# %%
# General imports
import numpy as np
import pandas as pd
import os, sys, gc, warnings, random, datetime

from sklearn import metrics
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import LabelEncoder

from tqdm import tqdm

import pickle

import math
warnings.filterwarnings('ignore')

# %%
########################### Helpers
#################################################################################
## Seeder
# :seed to make all processes deterministic     # type: int
def seed_everything(seed=0):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    
## Memory Reducer
# :df pandas dataframe to reduce size             # type: pd.DataFrame()
# :verbose                                        # type: bool
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: 
        print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 
                                                                              100*(start_mem - end_mem) / start_mem))
    return df

# %%
########################### Model
import lightgbm as lgb

def make_predictions(tr_df, tt_df, features_columns, target, lgb_params, NFOLDS=2):
    folds = KFold(n_splits=NFOLDS, shuffle=True, random_state=SEED)

    X,y = tr_df[features_columns], tr_df[target]    
    P,P_y = tt_df[features_columns], tt_df[target]  

    tt_df = tt_df[['TransactionID',target]]    
    predictions = np.zeros(len(tt_df))
    
    for fold_, (trn_idx, val_idx) in enumerate(folds.split(X, y)):
        print('Fold:',fold_)
        tr_x, tr_y = X.iloc[trn_idx,:], y[trn_idx]
        vl_x, vl_y = X.iloc[val_idx,:], y[val_idx]
            
        print(len(tr_x),len(vl_x))
        tr_data = lgb.Dataset(tr_x, label=tr_y)

        if LOCAL_TEST:
            vl_data = lgb.Dataset(P, label=P_y) 
        else:
            vl_data = lgb.Dataset(vl_x, label=vl_y)  

        estimator = lgb.train(
            lgb_params,
            tr_data,
            valid_sets = [tr_data, vl_data],
            verbose_eval = 200,
        )   
        
        pp_p = estimator.predict(P)
        predictions += pp_p/NFOLDS

        if LOCAL_TEST:
            feature_imp = pd.DataFrame(sorted(zip(estimator.feature_importance(),X.columns)), 
                                       columns=['Value','Feature'])
            print(feature_imp)
        
        del tr_x, tr_y, vl_x, vl_y, tr_data, vl_data
        gc.collect()
        
    tt_df['prediction'] = predictions
    
    return tt_df
## -------------------

# %%
########################### Vars
#################################################################################
SEED = 42
seed_everything(SEED)
LOCAL_TEST = False
TARGET = 'isFraud'
START_DATE = datetime.datetime.strptime('2017-11-30', '%Y-%m-%d')

# %%
########################### Model params
lgb_params = {
                    'objective':'binary',
                    'boosting_type':'gbdt',
                    'metric':'auc',
                    'n_jobs':-1,
                    'learning_rate':0.01,
                    'num_leaves': 2**8,
                    'max_depth':-1,
                    'tree_learner':'serial',
                    'colsample_bytree': 0.7,
                    'subsample_freq':1,
                    'subsample':0.7,
                    'n_estimators':800,
                    'max_bin':255,
                    'verbose':-1,
                    'seed': SEED,
                    'early_stopping_rounds':100, 
                }

# %%
########################### DATA LOAD
#################################################################################
print('Load Data')
train_df = pd.read_pickle('../../data/input/ieee-fe-with-some-eda/train_df.pkl')

if LOCAL_TEST:
    test_df = train_df[train_df['DT_M']==train_df['DT_M'].max()].reset_index(drop=True)
    train_df = train_df[train_df['DT_M']<(train_df['DT_M'].max()-1)].reset_index(drop=True)    
else:
    test_df = pd.read_pickle('../../data/input/ieee-fe-with-some-eda/test_df.pkl')

remove_features = pd.read_pickle('../../data/input/ieee-fe-with-some-eda/remove_features.pkl')
remove_features = list(remove_features['features_to_remove'].values)
print('Shape control:', train_df.shape, test_df.shape)
# Out:
# Load Data
# Shape control: (590540, 791) (506691, 791)

# %%
from lxml import html
import urllib.request
x_path_rank = '/html/body/div/div/table/tbody/tr/td[1]/div[1]/a'
x_path_traffic_rank = '/html/body/div/div/table/tbody/tr/td[2]/div[1]/a'
x_path_sites = '/html/body/div/div/table/tbody/tr/td[3]/div[1]/a'

alexa_cache = {}

# %%
def rank_domain(domain):
    if domain in ['', None, np.nan, 'nan']:
        return (None, None, None)
    
    if pd.isna(domain):
        return (None, None, None)
    
    if domain == 'gmail':
        domain = 'gmail.com'
    
    if domain in alexa_cache:
        return alexa_cache[domain]
    
    with urllib.request.urlopen(f"https://www.alexa.com/minisiteinfo/{domain}") as url:
        print(f'Querying Alexa for ranking of {domain}.')
        
        s = url.read()
        tree = html.fromstring(s)
        try:
            rank = int(tree.xpath(x_path_rank)[0].text_content().replace(',', ''))
        except IndexError:
            print(f'No rank for domain {domain}...')
            rank = None
        except ValueError:
            rank = 0
            
        try:
            traffic = int(tree.xpath(x_path_traffic_rank)[0].text_content().replace(',', ''))
        except IndexError:
            print(f'No rank for domain {domain}...')
            traffic = None
        except ValueError:
            traffic = 0
            
        try:
            sites = int(tree.xpath(x_path_sites)[0].text_content().replace(',', ''))
        except IndexError:
            print(f'No rank for domain {domain}...')
            sites = None       
        except ValueError:
            sites = 0
        
        alexa_cache[domain] = (rank, traffic, sites)
    
        return rank, traffic, sites

# %%
train_raw_emails, test_raw_emails = {}, {}
train_raw_emails['P_emaildomain'] = pickle.load(open('train_raw_Pemails.pickle', mode='rb'))
train_raw_emails['R_emaildomain'] = pickle.load(open('train_raw_Remails.pickle', mode='rb'))
test_raw_emails['P_emaildomain'] = pickle.load(open('test_raw_Pemails.pickle', mode='rb'))
test_raw_emails['R_emaildomain'] = pickle.load(open('test_raw_Remails.pickle', mode='rb'))

# %%
for c in ['P_emaildomain', 'R_emaildomain']:
    train_df[c + '_rank'] = [rank_domain(x)[0] for x in train_raw_emails[c].to_list()]
    test_df[c + '_rank'] = [rank_domain(x)[0] for x in test_raw_emails[c].to_list()]
    
    train_df[c + '_traffic_rank'] = [rank_domain(x)[1] for x in train_raw_emails[c].to_list()]
    test_df[c + '_traffic_rank'] = [rank_domain(x)[1] for x in test_raw_emails[c].to_list()]
    
    train_df[c + '_sites'] = [rank_domain(x)[2] for x in train_raw_emails[c].to_list()]
    test_df[c + '_sites'] = [rank_domain(x)[2] for x in test_raw_emails[c].to_list()]
# Out:
# Querying Alexa for ranking of gmail.com.
# Querying Alexa for ranking of outlook.com.
# Querying Alexa for ranking of yahoo.com.
# Querying Alexa for ranking of mail.com.
# Querying Alexa for ranking of anonymous.com.
# No rank for domain anonymous.com...
# Querying Alexa for ranking of hotmail.com.
# Querying Alexa for ranking of verizon.net.
# Querying Alexa for ranking of aol.com.
# Querying Alexa for ranking of me.com.
# No rank for domain me.com...
# Querying Alexa for ranking of comcast.net.
# Querying Alexa for ranking of optonline.net.
# Querying Alexa for ranking of cox.net.
# Querying Alexa for ranking of charter.net.
# Querying Alexa for ranking of rocketmail.com.
# No rank for domain rocketmail.com...
# Querying Alexa for ranking of prodigy.net.mx.
# Querying Alexa for ranking of embarqmail.com.
# No rank for domain embarqmail.com...
# Querying Alexa for ranking of icloud.com.
# Querying Alexa for ranking of live.com.mx.
# No rank for domain live.com.mx...
# Querying Alexa for ranking of live.com.
# Querying Alexa for ranking of att.net.
# Querying Alexa for ranking of juno.com.
# Querying Alexa for ranking of ymail.com.
# Querying Alexa for ranking of sbcglobal.net.
# No rank for domain sbcglobal.net...
# Querying Alexa for ranking of bellsouth.net.
# No rank for domain bellsouth.net...
# Querying Alexa for ranking of msn.com.
# Querying Alexa for ranking of q.com.
# No rank for domain q.com...
# Querying Alexa for ranking of yahoo.com.mx.
# No rank for domain yahoo.com.mx...
# Querying Alexa for ranking of centurylink.net.
# Querying Alexa for ranking of servicios-ta.com.
# No rank for domain servicios-ta.com...
# No rank for domain servicios-ta.com...
# Querying Alexa for ranking of earthlink.net.
# Querying Alexa for ranking of hotmail.es.
# No rank for domain hotmail.es...
# Querying Alexa for ranking of cfl.rr.com.
# Querying Alexa for ranking of roadrunner.com.
# Querying Alexa for ranking of netzero.net.
# Querying Alexa for ranking of gmx.de.
# No rank for domain gmx.de...
# Querying Alexa for ranking of suddenlink.net.
# Querying Alexa for ranking of frontiernet.net.
# Querying Alexa for ranking of windstream.net.
# Querying Alexa for ranking of frontier.com.
# Querying Alexa for ranking of outlook.es.
# No rank for domain outlook.es...
# Querying Alexa for ranking of mac.com.
# Querying Alexa for ranking of netzero.com.
# No rank for domain netzero.com...
# Querying Alexa for ranking of aim.com.
# Querying Alexa for ranking of web.de.
# Querying Alexa for ranking of twc.com.
# No rank for domain twc.com...
# Querying Alexa for ranking of cableone.net.
# Querying Alexa for ranking of yahoo.fr.
# No rank for domain yahoo.fr...
# Querying Alexa for ranking of yahoo.de.
# No rank for domain yahoo.de...
# Querying Alexa for ranking of yahoo.es.
# No rank for domain yahoo.es...
# Querying Alexa for ranking of sc.rr.com.
# Querying Alexa for ranking of ptd.net.
# Querying Alexa for ranking of live.fr.
# No rank for domain live.fr...
# Querying Alexa for ranking of yahoo.co.uk.
# No rank for domain yahoo.co.uk...
# Querying Alexa for ranking of hotmail.fr.
# No rank for domain hotmail.fr...
# Querying Alexa for ranking of hotmail.de.
# No rank for domain hotmail.de...
# Querying Alexa for ranking of hotmail.co.uk.
# No rank for domain hotmail.co.uk...
# Querying Alexa for ranking of protonmail.com.
# Querying Alexa for ranking of yahoo.co.jp.
# Querying Alexa for ranking of scranton.edu.

# %%
########################### Final features list
features_columns = [col for col in list(train_df) if col not in remove_features]

########################### Final Minification
train_df = reduce_mem_usage(train_df)
test_df  = reduce_mem_usage(test_df)
# Out:
# Mem. usage decreased to 1291.93 Mb (41.4% reduction)
# Mem. usage decreased to 1116.31 Mb (41.2% reduction)

# %%
train_df.iloc[2].to_dict()
# Out:
# {'TransactionID': 2987002,
#  'isFraud': 0,
#  'TransactionDT': 86469,
#  'TransactionAmt': 4.094,
#  'ProductCD': 0.0204,
#  'card1': 4664.0,
#  'card2': 490.0,
#  'card3': 150.0,
#  'card4': 719649.0,
#  'card5': 166.0,
#  'card6': 824959.0,
#  'addr1': 330.0,
#  'addr2': 87.0,
#  'dist1': 287.0,
#  'dist2': nan,
#  'P_emaildomain': 35,
#  'R_emaildomain': 49,
#  'C1': 1.0,
#  'C2': 1.0,
#  'C3': 0.0,
#  'C4': 0.0,
#  'C5': 0.0,
#  'C6': 1.0,
#  'C7': 0.0,
#  'C8': 0.0,
#  'C9': 1.0,
#  'C10': 0.0,
#  'C11': 1.0,
#  'C12': 0.0,
#  'C13': 1.0,
#  'C14': 1.0,
#  'D1': 507854,
#  'D2': 515566,
#  'D3': 466020,
#  'D4': 344864,
#  'D5': 534216,
#  'D6': 899261,
#  'D7': 998181,
#  'D8': 947967,
#  'D9': 947967,
#  'D10': 449929,
#  'D11': 487,
#  'D12': 963260,
#  'D13': 911895,
#  'D14': 919850,
#  'D15': 683,
#  'M1': 1.0,
#  'M2': 1.0,
#  'M3': 1.0,
#  'M4': 0.03665,
#  'M5': 0.0,
#  'M6': 0.0,
#  'M7': 0.0,
#  'M8': 0.0,
#  'M9': 0.0,
#  'V1': 1.0,
#  'V2': 1.0,
#  'V3': 1.0,
#  'V4': 1.0,
#  'V5': 1.0,
#  'V6': 1.0,
#  'V7': 1.0,
#  'V8': 1.0,
#  'V9': 1.0,
#  'V10': 0.0,
#  'V11': 0.0,
#  'V12': 1.0,
#  'V13': 1.0,
#  'V14': 1.0,
#  'V15': 0.0,
#  'V16': 0.0,
#  'V17': 0.0,
#  'V18': 0.0,
#  'V19': 1.0,
#  'V20': 1.0,
#  'V21': 0.0,
#  'V22': 0.0,
#  'V23': 1.0,
#  'V24': 1.0,
#  'V25': 1.0,
#  'V26': 1.0,
#  'V27': 0.0,
#  'V28': 0.0,
#  'V29': 0.0,
#  'V30': 0.0,
#  'V31': 0.0,
#  'V32': 0.0,
#  'V33': 0.0,
#  'V34': 0.0,
#  'V35': 1.0,
#  'V36': 1.0,
#  'V37': 1.0,
#  'V38': 1.0,
#  'V39': 0.0,
#  'V40': 0.0,
#  'V41': 1.0,
#  'V42': 0.0,
#  'V43': 0.0,
#  'V44': 1.0,
#  'V45': 1.0,
#  'V46': 1.0,
#  'V47': 1.0,
#  'V48': 0.0,
#  'V49': 0.0,
#  'V50': 0.0,
#  'V51': 0.0,
#  'V52': 0.0,
#  'V53': 1.0,
#  'V54': 1.0,
#  'V55': 1.0,
#  'V56': 1.0,
#  'V57': 0.0,
#  'V58': 0.0,
#  'V59': 0.0,
#  'V60': 0.0,
#  'V61': 1.0,
#  'V62': 1.0,
#  'V63': 0.0,
#  'V64': 0.0,
#  'V65': 1.0,
#  'V66': 1.0,
#  'V67': 1.0,
#  'V68': 0.0,
#  'V69': 0.0,
#  'V70': 0.0,
#  'V71': 0.0,
#  'V72': 0.0,
#  'V73': 0.0,
#  'V74': 0.0,
#  'V75': 1.0,
#  'V76': 1.0,
#  'V77': 1.0,
#  'V78': 1.0,
#  'V79': 0.0,
#  'V80': 0.0,
#  'V81': 0.0,
#  'V82': 1.0,
#  'V83': 1.0,
#  'V84': 0.0,
#  'V85': 0.0,
#  'V86': 1.0,
#  'V87': 1.0,
#  'V88': 1.0,
#  'V89': 0.0,
#  'V90': 0.0,
#  'V91': 0.0,
#  'V92': 0.0,
#  'V93': 0.0,
#  'V94': 0.0,
#  'V95': 0.0,
#  'V96': 0.0,
#  'V97': 0.0,
#  'V98': 0.0,
#  'V99': 0.0,
#  'V100': 0.0,
#  'V101': 0.0,
#  'V102': 0.0,
#  'V103': 0.0,
#  'V104': 0.0,
#  'V105': 0.0,
#  'V106': 0.0,
#  'V107': 1.0,
#  'V108': 1.0,
#  'V109': 1.0,
#  'V110': 1.0,
#  'V111': 1.0,
#  'V112': 1.0,
#  'V113': 1.0,
#  'V114': 1.0,
#  'V115': 1.0,
#  'V116': 1.0,
#  'V117': 1.0,
#  'V118': 1.0,
#  'V119': 1.0,
#  'V120': 1.0,
#  'V121': 1.0,
#  'V122': 1.0,
#  'V123': 1.0,
#  'V124': 1.0,
#  'V125': 1.0,
#  'V126': 0.0,
#  'V127': 0.0,
#  'V128': 0.0,
#  'V129': 0.0,
#  'V130': 0.0,
#  'V131': 0.0,
#  'V132': 0.0,
#  'V133': 0.0,
#  'V134': 0.0,
#  'V135': 0.0,
#  'V136': 0.0,
#  'V137': 0.0,
#  'V138': nan,
#  'V139': nan,
#  'V140': nan,
#  'V141': nan,
#  'V142': nan,
#  'V143': nan,
#  'V144': nan,
#  'V145': nan,
#  'V146': nan,
#  'V147': nan,
#  'V148': nan,
#  'V149': nan,
#  'V150': nan,
#  'V151': nan,
#  'V152': nan,
#  'V153': nan,
#  'V154': nan,
#  'V155': nan,
#  'V156': nan,
#  'V157': nan,
#  'V158': nan,
#  'V159': nan,
#  'V160': nan,
#  'V161': nan,
#  'V162': nan,
#  'V163': nan,
#  'V164': nan,
#  'V165': nan,
#  'V166': nan,
#  'V167': nan,
#  'V168': nan,
#  'V169': nan,
#  'V170': nan,
#  'V171': nan,
#  'V172': nan,
#  'V173': nan,
#  'V174': nan,
#  'V175': nan,
#  'V176': nan,
#  'V177': nan,
#  'V178': nan,
#  'V179': nan,
#  'V180': nan,
#  'V181': nan,
#  'V182': nan,
#  'V183': nan,
#  'V184': nan,
#  'V185': nan,
#  'V186': nan,
#  'V187': nan,
#  'V188': nan,
#  'V189': nan,
#  'V190': nan,
#  'V191': nan,
#  'V192': nan,
#  'V193': nan,
#  'V194': nan,
#  'V195': nan,
#  'V196': nan,
#  'V197': nan,
#  'V198': nan,
#  'V199': nan,
#  'V200': nan,
#  'V201': nan,
#  'V202': nan,
#  'V203': nan,
#  'V204': nan,
#  'V205': nan,
#  'V206': nan,
#  'V207': nan,
#  'V208': nan,
#  'V209': nan,
#  'V210': nan,
#  'V211': nan,
#  'V212': nan,
#  'V213': nan,
#  'V214': nan,
#  'V215': nan,
#  'V216': nan,
#  'V217': nan,
#  'V218': nan,
#  'V219': nan,
#  'V220': nan,
#  'V221': nan,
#  'V222': nan,
#  'V223': nan,
#  'V224': nan,
#  'V225': nan,
#  'V226': nan,
#  'V227': nan,
#  'V228': nan,
#  'V229': nan,
#  'V230': nan,
#  'V231': nan,
#  'V232': nan,
#  'V233': nan,
#  'V234': nan,
#  'V235': nan,
#  'V236': nan,
#  'V237': nan,
#  'V238': nan,
#  'V239': nan,
#  'V240': nan,
#  'V241': nan,
#  'V242': nan,
#  'V243': nan,
#  'V244': nan,
#  'V245': nan,
#  'V246': nan,
#  'V247': nan,
#  'V248': nan,
#  'V249': nan,
#  'V250': nan,
#  'V251': nan,
#  'V252': nan,
#  'V253': nan,
#  'V254': nan,
#  'V255': nan,
#  'V256': nan,
#  'V257': nan,
#  'V258': nan,
#  'V259': nan,
#  'V260': nan,
#  'V261': nan,
#  'V262': nan,
#  'V263': nan,
#  'V264': nan,
#  'V265': nan,
#  'V266': nan,
#  'V267': nan,
#  'V268': nan,
#  'V269': nan,
#  'V270': nan,
#  'V271': nan,
#  'V272': nan,
#  'V273': nan,
#  'V274': nan,
#  'V275': nan,
#  'V276': nan,
#  'V277': nan,
#  'V278': nan,
#  'V279': 0.0,
#  'V280': 0.0,
#  'V281': 0.0,
#  'V282': 1.0,
#  'V283': 1.0,
#  'V284': 0.0,
#  'V285': 0.0,
#  'V286': 0.0,
#  'V287': 0.0,
#  'V288': 0.0,
#  'V289': 0.0,
#  'V290': 1.0,
#  'V291': 1.0,
#  'V292': 1.0,
#  'V293': 0.0,
#  'V294': 0.0,
#  'V295': 0.0,
#  'V296': 0.0,
#  'V297': 0.0,
#  'V298': 0.0,
#  'V299': 0.0,
#  'V300': 0.0,
#  'V301': 0.0,
#  'V302': 0.0,
#  'V303': 0.0,
#  'V304': 0.0,
#  'V305': 1.0,
#  'V306': 0.0,
#  'V307': 0.0,
#  'V308': 0.0,
#  'V309': 0.0,
#  'V310': 0.0,
#  'V311': 0.0,
#  'V312': 0.0,
#  'V313': 0.0,
#  'V314': 0.0,
#  'V315': 0.0,
#  'V316': 0.0,
#  'V317': 0.0,
#  'V318': 0.0,
#  'V319': 0.0,
#  'V320': 0.0,
#  'V321': 0.0,
#  'V322': nan,
#  'V323': nan,
#  'V324': nan,
#  'V325': nan,
#  'V326': nan,
#  'V327': nan,
#  'V328': nan,
#  'V329': nan,
#  'V330': nan,
#  'V331': nan,
#  'V332': nan,
#  'V333': nan,
#  'V334': nan,
#  'V335': nan,
#  'V336': nan,
#  'V337': nan,
#  'V338': nan,
#  'V339': nan,
#  'DT': Timestamp('2017-12-01 00:01:09'),
#  'DT_M': 12,
#  'DT_W': 48,
#  'DT_D': 335,
#  'DT_hour': 0,
#  'DT_day_week': 4,
#  'DT_day_month': 1,
#  'is_december': 1,
#  'is_holiday': 0,
#  'DT_M_total': 137321,
#  'DT_W_total': 12093,
#  'DT_D_total': 5122,
#  'uid': 7350,
#  'uid2': 7616,
#  'uid3': 34475,
#  'uid4': 85989,
#  'uid5': 60241,
#  'card1_fq_enc': 1794,
#  'card2_fq_enc': 70496,
#  'card3_fq_enc': 956845,
#  'card5_fq_enc': 102930,
#  'uid_fq_enc': 1787,
#  'uid2_fq_enc': 1787,
#  'uid3_fq_enc': 46,
#  'uid4_fq_enc': 4,
#  'uid5_fq_enc': 45,
#  'bank_type': 343,
#  'card3_DT_D_hour_dist': -14.68,
#  'card3_DT_W_week_day_dist': -0.8384,
#  'card3_DT_M_month_day_dist': -15.13,
#  'card3_DT_D_hour_dist_best': -16.0,
#  'card3_DT_W_week_day_dist_best': 0.0,
#  'card3_DT_M_month_day_dist_best': -21.0,
#  'card5_DT_D_hour_dist': -16.0,
#  'card5_DT_W_week_day_dist': -0.7603,
#  'card5_DT_M_month_day_dist': -14.22,
#  'card5_DT_D_hour_dist_best': -21.0,
#  'card5_DT_W_week_day_dist_best': 0.0,
#  'card5_DT_M_month_day_dist_best': 0.0,
#  'bank_type_DT_D_hour_dist': -16.03,
#  'bank_type_DT_W_week_day_dist': -0.758,
#  'bank_type_DT_M_month_day_dist': -14.19,
#  'bank_type_DT_D_hour_dist_best': -21,
#  'bank_type_DT_W_week_day_dist_best': 0,
#  'bank_type_DT_M_month_day_dist_best': 0,
#  'bank_type_DT_M': 0.074,
#  'bank_type_DT_W': 0.1233,
#  'bank_type_DT_D': 0.1365,
#  'uid_D1_mean': 51.8,
#  'uid_D1_std': 93.0625,
#  'uid2_D1_mean': 51.8,
#  'uid2_D1_std': 93.0625,
#  'uid3_D1_mean': 22.61,
#  'uid3_D1_std': 51.96875,
#  'uid4_D1_mean': 97.75,
#  'uid4_D1_std': 71.25,
#  'uid5_D1_mean': 23.11,
#  'uid5_D1_std': 52.46875,
#  'bank_type_D1_mean': 85.8,
#  'bank_type_D1_std': 143.75,
#  'uid_D2_mean': 88.6,
#  'uid_D2_std': 107.125,
#  'uid2_D2_mean': 88.6,
#  'uid2_D2_std': 107.125,
#  'uid3_D2_mean': 86.7,
#  'uid3_D2_std': 70.6875,
#  'uid4_D2_mean': 130.4,
#  'uid4_D2_std': 35.3125,
#  'uid5_D2_mean': 86.7,
#  'uid5_D2_std': 70.6875,
#  'bank_type_D2_mean': 140.0,
#  'bank_type_D2_std': 160.5,
#  'uid_D3_mean': 22.84,
#  'uid_D3_std': 49.125,
#  'uid2_D3_mean': 22.84,
#  'uid2_D3_std': 49.125,
#  'uid3_D3_mean': 46.5,
#  'uid3_D3_std': 62.3125,
#  'uid4_D3_mean': 51.66,
#  'uid4_D3_std': 42.65625,
#  'uid5_D3_mean': 46.5,
#  'uid5_D3_std': 62.3125,
#  'bank_type_D3_mean': 27.9,
#  'bank_type_D3_std': 61.125,
#  'uid_D4_mean': 130.1,
#  'uid_D4_std': 188.625,
#  'uid2_D4_mean': 130.1,
#  'uid2_D4_std': 188.625,
#  'uid3_D4_mean': 84.2,
#  'uid3_D4_std': 157.5,
#  'uid4_D4_mean': 98.25,
#  'uid4_D4_std': 71.75,
#  'uid5_D4_mean': 84.2,
#  'uid5_D4_std': 157.5,
#  'bank_type_D4_mean': 142.4,
#  'bank_type_D4_std': 201.875,
#  'uid_D5_mean': 51.4,
#  'uid_D5_std': 106.875,
#  'uid2_D5_mean': 51.4,
#  'uid2_D5_std': 106.875,
#  'uid3_D5_mean': 82.0,
#  'uid3_D5_std': 99.9375,
#  'uid4_D5_mean': 56.34,
#  'uid4_D5_std': 36.84375,
#  'uid5_D5_mean': 82.0,
#  'uid5_D5_std': 99.9375,
#  'bank_type_D5_mean': 46.75,
#  'bank_type_D5_std': 98.0,
#  'uid_D6_mean': nan,
#  'uid_D6_std': nan,
#  'uid2_D6_mean': nan,
#  'uid2_D6_std': nan,
#  'uid3_D6_mean': nan,
#  'uid3_D6_std': nan,
#  'uid4_D6_mean': nan,
#  'uid4_D6_std': nan,
#  'uid5_D6_mean': nan,
#  'uid5_D6_std': nan,
#  'bank_type_D6_mean': 115.5,
#  'bank_type_D6_std': 199.125,
#  'uid_D7_mean': nan,
#  'uid_D7_std': nan,
#  'uid2_D7_mean': nan,
#  'uid2_D7_std': nan,
#  'uid3_D7_mean': nan,
#  'uid3_D7_std': nan,
#  'uid4_D7_mean': nan,
#  'uid4_D7_std': nan,
#  'uid5_D7_mean': nan,
#  'uid5_D7_std': nan,
#  'bank_type_D7_mean': 34.84,
#  'bank_type_D7_std': 110.625,
#  'uid_D8_mean': 131.4,
#  'uid_D8_std': 113.1875,
#  'uid2_D8_mean': 131.4,
#  'uid2_D8_std': 113.1875,
#  'uid3_D8_mean': nan,
#  'uid3_D8_std': nan,
#  'uid4_D8_mean': nan,
#  'uid4_D8_std': nan,
#  'uid5_D8_mean': nan,
#  'uid5_D8_std': nan,
#  'bank_type_D8_mean': 123.6,
#  'bank_type_D8_std': 213.25,
#  'uid_D9_mean': 0.7363,
#  'uid_D9_std': 0.02396,
#  'uid2_D9_mean': 0.7363,
#  'uid2_D9_std': 0.02396,
#  'uid3_D9_mean': nan,
#  'uid3_D9_std': nan,
#  'uid4_D9_mean': nan,
#  'uid4_D9_std': nan,
#  'uid5_D9_mean': nan,
#  'uid5_D9_std': nan,
#  'bank_type_D9_mean': 0.566,
#  'bank_type_D9_std': 0.3013,
#  'uid_D10_mean': 107.3,
#  'uid_D10_std': 174.25,
#  'uid2_D10_mean': 107.3,
#  'uid2_D10_std': 174.25,
#  'uid3_D10_mean': 63.1,
#  'uid3_D10_std': 139.75,
#  'uid4_D10_mean': 98.25,
#  'uid4_D10_std': 71.75,
#  'uid5_D10_mean': 63.1,
#  'uid5_D10_std': 139.75,
#  'bank_type_D10_mean': 128.0,
#  'bank_type_D10_std': 191.375,
#  'uid_D11_mean': 98.56,
#  'uid_D11_std': 159.125,
#  'uid2_D11_mean': 98.56,
#  'uid2_D11_std': 159.125,
#  'uid3_D11_mean': 150.2,
#  'uid3_D11_std': 193.875,
#  'uid4_D11_mean': 413.2,
#  'uid4_D11_std': 71.75,
#  'uid5_D11_mean': 150.2,
#  'uid5_D11_std': 193.875,
#  'bank_type_D11_mean': 136.2,
#  'bank_type_D11_std': 194.25,
#  'uid_D12_mean': nan,
#  'uid_D12_std': nan,
#  'uid2_D12_mean': nan,
#  'uid2_D12_std': nan,
#  'uid3_D12_mean': nan,
#  'uid3_D12_std': nan,
#  'uid4_D12_mean': nan,
#  'uid4_D12_std': nan,
#  'uid5_D12_mean': nan,
#  'uid5_D12_std': nan,
#  'bank_type_D12_mean': 9.87,
#  'bank_type_D12_std': 35.8125,
#  'uid_D13_mean': nan,
#  'uid_D13_std': nan,
#  'uid2_D13_mean': nan,
#  'uid2_D13_std': nan,
#  'uid3_D13_mean': nan,
#  'uid3_D13_std': nan,
#  'uid4_D13_mean': nan,
#  'uid4_D13_std': nan,
#  'uid5_D13_mean': nan,
#  'uid5_D13_std': nan,
#  'bank_type_D13_mean': 15.336,
#  'bank_type_D13_std': 59.21875,
#  'uid_D14_mean': nan,
#  'uid_D14_std': nan,
#  'uid2_D14_mean': nan,
#  'uid2_D14_std': nan,
#  'uid3_D14_mean': nan,
#  'uid3_D14_std': nan,
#  'uid4_D14_mean': nan,
#  'uid4_D14_std': nan,
#  'uid5_D14_mean': nan,
#  'uid5_D14_std': nan,
#  'bank_type_D14_mean': 54.66,
#  'bank_type_D14_std': 146.25,
#  'uid_D15_mean': 143.9,
#  'uid_D15_std': 199.5,
#  'uid2_D15_mean': 143.9,
#  'uid2_D15_std': 199.5,
#  'uid3_D15_mean': 145.2,
#  'uid3_D15_std': 203.125,
#  'uid4_D15_mean': 413.2,
#  'uid4_D15_std': 71.75,
#  'uid5_D15_mean': 145.2,
#  'uid5_D15_std': 203.125,
#  'bank_type_D15_mean': 167.0,
#  'bank_type_D15_std': 216.25,
#  'D9_not_na': 0,
#  'D8_not_same_day': 0,
#  'D8_D9_decimal_dist': nan,
#  'D3_DT_D_min_max': nan,
#  'D3_DT_D_std_score': nan,
#  'D4_DT_D_min_max': 0.0,
#  'D4_DT_D_std_score': -0.918,
#  'D5_DT_D_min_max': nan,
#  'D5_DT_D_std_score': nan,
#  'D6_DT_D_min_max': nan,
#  'D6_DT_D_std_score': nan,
#  'D7_DT_D_min_max': nan,
#  'D7_DT_D_std_score': nan,
#  'D8_DT_D_min_max': 0.0,
#  'D8_DT_D_std_score': -0.1857,
#  'D10_DT_D_min_max': 0.0,
#  'D10_DT_D_std_score': -0.7866,
#  'D11_DT_D_min_max': 0.6494,
#  'D11_DT_D_std_score': 0.9736,
#  'D12_DT_D_min_max': nan,
#  'D12_DT_D_std_score': nan,
#  'D13_DT_D_min_max': nan,
#  'D13_DT_D_std_score': nan,
#  'D14_DT_D_min_max': nan,
#  'D14_DT_D_std_score': nan,
#  'D15_DT_D_min_max': 0.4531,
#  'D15_DT_D_std_score': 0.641,
#  'D3_DT_W_min_max': nan,
#  'D3_DT_W_std_score': nan,
#  'D4_DT_W_min_max': 0.0,
#  'D4_DT_W_std_score': -0.9517,
#  'D5_DT_W_min_max': nan,
#  'D5_DT_W_std_score': nan,
#  'D6_DT_W_min_max': nan,
#  'D6_DT_W_std_score': nan,
#  'D7_DT_W_min_max': nan,
#  'D7_DT_W_std_score': nan,
#  'D8_DT_W_min_max': 0.0,
#  'D8_DT_W_std_score': -0.1881,
#  'D10_DT_W_min_max': 0.0,
#  'D10_DT_W_std_score': -0.768,
#  'D11_DT_W_min_max': 0.6455,
#  'D11_DT_W_std_score': 0.925,
#  'D12_DT_W_min_max': nan,
#  'D12_DT_W_std_score': nan,
#  'D13_DT_W_min_max': nan,
#  'D13_DT_W_std_score': nan,
#  'D14_DT_W_min_max': nan,
#  'D14_DT_W_std_score': nan,
#  'D15_DT_W_min_max': 0.4531,
#  'D15_DT_W_std_score': 0.6255,
#  'D3_DT_M_min_max': nan,
#  'D3_DT_M_std_score': nan,
#  'D4_DT_M_min_max': 0.0,
#  'D4_DT_M_std_score': -0.7373,
#  'D5_DT_M_min_max': nan,
#  'D5_DT_M_std_score': nan,
#  'D6_DT_M_min_max': nan,
#  'D6_DT_M_std_score': nan,
#  'D7_DT_M_min_max': nan,
#  'D7_DT_M_std_score': nan,
#  'D8_DT_M_min_max': 0.0,
#  'D8_DT_M_std_score': -0.272,
#  'D10_DT_M_min_max': 0.0,
#  'D10_DT_M_std_score': -0.688,
#  'D11_DT_M_min_max': 0.6035,
#  'D11_DT_M_std_score': 1.233,
#  'D12_DT_M_min_max': nan,
#  'D12_DT_M_std_score': nan,
#  'D13_DT_M_min_max': nan,
#  'D13_DT_M_std_score': nan,
#  'D14_DT_M_min_max': nan,
#  'D14_DT_M_std_score': nan,
#  'D15_DT_M_min_max': 0.4338,
#  'D15_DT_M_std_score': 0.9375,
#  'D1_scaled': 0.0,
#  'D2_scaled': nan,
#  'TransactionAmt_check': 1,
#  'card1_TransactionAmt_mean': 104.9,
#  'card1_TransactionAmt_std': 130.4,
#  'card2_TransactionAmt_mean': 136.1,
#  'card2_TransactionAmt_std': 227.6,
#  'card3_TransactionAmt_mean': 147.5,
#  'card3_TransactionAmt_std': 249.4,
#  'card5_TransactionAmt_mean': 98.75,
#  'card5_TransactionAmt_std': 141.0,
#  'uid_TransactionAmt_mean': 104.8,
#  'uid_TransactionAmt_std': 130.4,
#  'uid2_TransactionAmt_mean': 104.8,
#  'uid2_TransactionAmt_std': 130.4,
#  'uid3_TransactionAmt_mean': 65.7,
#  'uid3_TransactionAmt_std': 55.2,
#  'uid4_TransactionAmt_mean': 73.5,
#  'uid4_TransactionAmt_std': 17.06,
#  'uid5_TransactionAmt_mean': 65.5,
#  'uid5_TransactionAmt_std': 55.78,
#  'bank_type_TransactionAmt_mean': 99.5,
#  'bank_type_TransactionAmt_std': 141.8,
#  'TransactionAmt_DT_D_min_max': 0.0176,
#  'TransactionAmt_DT_D_std_score': -0.3462,
#  'TransactionAmt_DT_W_min_max': 0.01425,
#  'TransactionAmt_DT_W_std_score': -0.326,
#  'TransactionAmt_DT_M_min_max': 0.01174,
#  'TransactionAmt_DT_M_std_score': -0.344,
#  'product_type': 57946,
#  'product_type_DT_D': 0.03592,
#  'product_type_DT_W': 0.03662,
#  'product_type_DT_M': 0.03284,
#  'C1_fq_enc': 586742,
#  'C2_fq_enc': 581696,
#  'C3_fq_enc': 1081890,
#  'C4_fq_enc': 823454,
#  'C5_fq_enc': 707008,
#  'C6_fq_enc': 631237,
#  'C7_fq_enc': 961237,
#  'C8_fq_enc': 816304,
#  'C9_fq_enc': 420354,
#  'C10_fq_enc': 824420,
#  'C11_fq_enc': 731792,
#  'C12_fq_enc': 856080,
#  'C13_fq_enc': 367617,
#  'C14_fq_enc': 598520,
#  'id_01': nan,
#  'id_02': nan,
#  'id_03': nan,
#  'id_04': nan,
#  'id_05': nan,
#  'id_06': nan,
#  'id_07': nan,
#  'id_08': nan,
#  'id_09': nan,
#  'id_10': nan,
#  'id_11': nan,
#  'id_12': nan,
#  'id_13': nan,
#  'id_14': nan,
#  'id_15': nan,
#  'id_16': nan,
#  'id_17': nan,
#  'id_18': nan,
#  'id_19': nan,
#  'id_20': nan,
#  'id_21': nan,
#  'id_22': nan,
#  'id_23': nan,
#  'id_24': nan,
#  'id_25': nan,
#  'id_26': nan,
#  'id_27': nan,
#  'id_28': nan,
#  'id_29': nan,
#  'id_30': 811091,
#  'id_31': 811091,
#  'id_32': nan,
#  'id_33': 811091,
#  'id_34': nan,
#  'id_35': nan,
#  'id_36': nan,
#  'id_37': nan,
#  'id_38': nan,
#  'DeviceType': 2,
#  'DeviceInfo': 811091,
#  'id_33_0': nan,
#  'id_33_1': nan,
#  'DeviceInfo_device': 811091,
#  'DeviceInfo_version': 811091,
#  'id_30_device': 811091,
#  'id_30_version': 811091,
#  'id_31_device': 811091,
#  'P_emaildomain_rank': 2564.0,
#  'P_emaildomain_traffic_rank': 910.0,
#  'P_emaildomain_sites': 5495.0,
#  'R_emaildomain_rank': nan,
#  'R_emaildomain_traffic_rank': nan,
#  'R_emaildomain_sites': nan}

# %%
########################### Model Train
if LOCAL_TEST:
    lgb_params['learning_rate'] = 0.01
    lgb_params['n_estimators'] = 20000
    lgb_params['early_stopping_rounds'] = 100
    test_predictions = make_predictions(train_df, test_df, features_columns, TARGET, lgb_params)
    print(metrics.roc_auc_score(test_predictions[TARGET], test_predictions['prediction']))
else:
    lgb_params['learning_rate'] = 0.005
    lgb_params['n_estimators'] = 1800
    lgb_params['early_stopping_rounds'] = 100    
    test_predictions = make_predictions(train_df, test_df, features_columns, TARGET, lgb_params, NFOLDS=8)
# Out:
# Fold: 0
# 516722 73818
# Training until validation scores don't improve for 100 rounds.
# [200]	training's auc: 0.949151	valid_1's auc: 0.932875
# [400]	training's auc: 0.974908	valid_1's auc: 0.950543
# [600]	training's auc: 0.988108	valid_1's auc: 0.961124
# [800]	training's auc: 0.994375	valid_1's auc: 0.967363
# [1000]	training's auc: 0.997391	valid_1's auc: 0.97067
# [1200]	training's auc: 0.998753	valid_1's auc: 0.972998
# [1400]	training's auc: 0.999387	valid_1's auc: 0.97437
# [1600]	training's auc: 0.999691	valid_1's auc: 0.97546
# [1800]	training's auc: 0.999844	valid_1's auc: 0.976297
# Did not meet early stopping. Best iteration is:
# [1800]	training's auc: 0.999844	valid_1's auc: 0.976297
# Fold: 1
# 516722 73818
# Training until validation scores don't improve for 100 rounds.
# [200]	training's auc: 0.949678	valid_1's auc: 0.932012
# [400]	training's auc: 0.974743	valid_1's auc: 0.95126
# [600]	training's auc: 0.98822	valid_1's auc: 0.962914
# [800]	training's auc: 0.994405	valid_1's auc: 0.969128
# [1000]	training's auc: 0.997348	valid_1's auc: 0.972712
# [1200]	training's auc: 0.998732	valid_1's auc: 0.974839
# [1400]	training's auc: 0.999382	valid_1's auc: 0.976266
# [1600]	training's auc: 0.999694	valid_1's auc: 0.977297
# [1800]	training's auc: 0.999847	valid_1's auc: 0.978145
# Did not meet early stopping. Best iteration is:
# [1800]	training's auc: 0.999847	valid_1's auc: 0.978145
# Fold: 2
# 516722 73818
# Training until validation scores don't improve for 100 rounds.
# [200]	training's auc: 0.948954	valid_1's auc: 0.926293
# [400]	training's auc: 0.974607	valid_1's auc: 0.947734
# [600]	training's auc: 0.987844	valid_1's auc: 0.95942
# [800]	training's auc: 0.994306	valid_1's auc: 0.965965
# [1000]	training's auc: 0.997327	valid_1's auc: 0.969738
# [1200]	training's auc: 0.998721	valid_1's auc: 0.972038
# [1400]	training's auc: 0.999375	valid_1's auc: 0.973547
# [1600]	training's auc: 0.999686	valid_1's auc: 0.974661
# [1800]	training's auc: 0.999839	valid_1's auc: 0.975514
# Did not meet early stopping. Best iteration is:
# [1800]	training's auc: 0.999839	valid_1's auc: 0.975514
# Fold: 3
# 516722 73818
# Training until validation scores don't improve for 100 rounds.
# [200]	training's auc: 0.949154	valid_1's auc: 0.932898
# [400]	training's auc: 0.975219	valid_1's auc: 0.950546
# [600]	training's auc: 0.988271	valid_1's auc: 0.961258
# [800]	training's auc: 0.994486	valid_1's auc: 0.966864
# [1000]	training's auc: 0.997335	valid_1's auc: 0.970044
# [1200]	training's auc: 0.99871	valid_1's auc: 0.972118
# [1400]	training's auc: 0.999368	valid_1's auc: 0.97347
# [1600]	training's auc: 0.999678	valid_1's auc: 0.974543
# [1800]	training's auc: 0.99984	valid_1's auc: 0.975226
# Did not meet early stopping. Best iteration is:
# [1800]	training's auc: 0.99984	valid_1's auc: 0.975226
# Fold: 4
# 516723 73817
# Training until validation scores don't improve for 100 rounds.
# [200]	training's auc: 0.949252	valid_1's auc: 0.92851
# [400]	training's auc: 0.975365	valid_1's auc: 0.948694
# [600]	training's auc: 0.988061	valid_1's auc: 0.960168
# [800]	training's auc: 0.994331	valid_1's auc: 0.966134
# [1000]	training's auc: 0.99735	valid_1's auc: 0.970066
# [1200]	training's auc: 0.998733	valid_1's auc: 0.972383
# [1400]	training's auc: 0.999368	valid_1's auc: 0.973843
# [1600]	training's auc: 0.999682	valid_1's auc: 0.975041
# [1800]	training's auc: 0.999837	valid_1's auc: 0.975812
# Did not meet early stopping. Best iteration is:
# [1800]	training's auc: 0.999837	valid_1's auc: 0.975812
# Fold: 5
# 516723 73817
# Training until validation scores don't improve for 100 rounds.
# [200]	training's auc: 0.949614	valid_1's auc: 0.930857
# [400]	training's auc: 0.975048	valid_1's auc: 0.948018
# [600]	training's auc: 0.988322	valid_1's auc: 0.95937
# [800]	training's auc: 0.994442	valid_1's auc: 0.965426
# [1000]	training's auc: 0.997332	valid_1's auc: 0.969029
# [1200]	training's auc: 0.99873	valid_1's auc: 0.971542
# [1400]	training's auc: 0.999376	valid_1's auc: 0.973092
# [1600]	training's auc: 0.999686	valid_1's auc: 0.974134
# [1800]	training's auc: 0.99984	valid_1's auc: 0.975002
# Did not meet early stopping. Best iteration is:
# [1800]	training's auc: 0.99984	valid_1's auc: 0.975002
# Fold: 6
# 516723 73817
# Training until validation scores don't improve for 100 rounds.
# [200]	training's auc: 0.949769	valid_1's auc: 0.930406
# [400]	training's auc: 0.975378	valid_1's auc: 0.947469
# [600]	training's auc: 0.988047	valid_1's auc: 0.958429
# [800]	training's auc: 0.994326	valid_1's auc: 0.964608
# [1000]	training's auc: 0.997305	valid_1's auc: 0.968203
# [1200]	training's auc: 0.998706	valid_1's auc: 0.970525
# [1400]	training's auc: 0.999369	valid_1's auc: 0.971996
# [1600]	training's auc: 0.999683	valid_1's auc: 0.973115
# [1800]	training's auc: 0.99984	valid_1's auc: 0.973915
# Did not meet early stopping. Best iteration is:
# [1800]	training's auc: 0.99984	valid_1's auc: 0.973915
# Fold: 7
# 516723 73817
# Training until validation scores don't improve for 100 rounds.
# [200]	training's auc: 0.949172	valid_1's auc: 0.924316
# [400]	training's auc: 0.974886	valid_1's auc: 0.943466
# [600]	training's auc: 0.988017	valid_1's auc: 0.955898
# [800]	training's auc: 0.994342	valid_1's auc: 0.962932
# [1000]	training's auc: 0.997309	valid_1's auc: 0.967162
# [1200]	training's auc: 0.998727	valid_1's auc: 0.96958
# [1400]	training's auc: 0.999375	valid_1's auc: 0.971053
# [1600]	training's auc: 0.999685	valid_1's auc: 0.972197
# [1800]	training's auc: 0.99984	valid_1's auc: 0.973148
# Did not meet early stopping. Best iteration is:
# [1800]	training's auc: 0.99984	valid_1's auc: 0.973148

# %%
########################### Export
if not LOCAL_TEST:
    test_predictions['isFraud'] = test_predictions['prediction']
    test_predictions[['TransactionID','isFraud']].to_csv('submission-20190916-A.csv', index=False)
